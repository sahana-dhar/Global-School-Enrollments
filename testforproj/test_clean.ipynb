# %%
import pandas as pd
data = pd.read_csv('global_country_data_copy.csv', skiprows=4)
df = pd.DataFrame(data)
df1 = df.copy()
df
# Out:
#       Country Name Country Code  \
# 0            Aruba          ABW
# 1            Aruba          ABW
# 2            Aruba          ABW
# 3            Aruba          ABW
# 4            Aruba          ABW
# ...            ...          ...
# 43619     Zimbabwe          ZWE
# 43620     Zimbabwe          ZWE
# 43621     Zimbabwe          ZWE
# 43622     Zimbabwe          ZWE
# 43623     Zimbabwe          ZWE
#
#                                           Indicator Name  \
# 0          Population ages 15-64 (% of total population)
# 1           Population ages 0-14 (% of total population)
# 2      Unemployment, total (% of total labor force) (...
# 3      Unemployment, male (% of male labor force) (mo...
# 4      Unemployment, female (% of female labor force)...
# ...                                                  ...
# 43619  Literacy rate, adult female (% of females ages...
# 43620  Literacy rate, youth total (% of people ages 1...
# 43621  Literacy rate, youth male (% of males ages 15-24)
# 43622  Literacy rate, youth (ages 15-24), gender pari...
# 43623  Literacy rate, youth female (% of females ages...
#
#              Indicator Code       1960       1961       1962       1963  \
# 0         SP.POP.1564.TO.ZS  54.495678  54.588701  54.585630  54.674206
# 1         SP.POP.0014.TO.ZS  43.131043  42.949419  42.852732  42.661157
# 2            SL.UEM.TOTL.ZS        NaN        NaN        NaN        NaN
# 3         SL.UEM.TOTL.MA.ZS        NaN        NaN        NaN        NaN
# 4         SL.UEM.TOTL.FE.ZS        NaN        NaN        NaN        NaN
# ...                     ...        ...        ...        ...        ...
# 43619     SE.ADT.LITR.FE.ZS        NaN        NaN        NaN        NaN
# 43620     SE.ADT.1524.LT.ZS        NaN        NaN        NaN        NaN
# 43621  SE.ADT.1524.LT.MA.ZS        NaN        NaN        NaN        NaN
# 43622  SE.ADT.1524.LT.FM.ZS        NaN        NaN        NaN        NaN
# 43623  SE.ADT.1524.LT.FE.ZS        NaN        NaN        NaN        NaN
#
#             1964       1965  ...       2014       2015       2016       2017  \
# 0      54.873448  55.181477  ...  69.620827  69.352325  69.027743  68.681269
# 1      42.359159  41.936664  ...  19.045505  18.799607  18.571721  18.334859
# 2            NaN        NaN  ...        NaN        NaN        NaN        NaN
# 3            NaN        NaN  ...        NaN        NaN        NaN        NaN
# 4            NaN        NaN  ...        NaN        NaN        NaN        NaN
# ...          ...        ...  ...        ...        ...        ...        ...
# 43619        NaN        NaN  ...  88.283829        NaN        NaN        NaN
# 43620        NaN        NaN  ...  90.428123        NaN        NaN        NaN
# 43621        NaN        NaN  ...  87.591858        NaN        NaN        NaN
# 43622        NaN        NaN  ...   1.060060        NaN        NaN        NaN
# 43623        NaN        NaN  ...  93.188347        NaN        NaN        NaN
#
#             2018       2019       2020       2021       2022  Unnamed: 67
# 0      68.320569  67.962515  67.712003  67.657094  67.617079          NaN
# 1      18.069771  17.767339  17.351022  16.799407  16.240782          NaN
# 2            NaN        NaN        NaN        NaN        NaN          NaN
# 3            NaN        NaN        NaN        NaN        NaN          NaN
# 4            NaN        NaN        NaN        NaN        NaN          NaN
# ...          ...        ...        ...        ...        ...          ...
# 43619        NaN        NaN        NaN        NaN  91.199997          NaN
# 43620        NaN  83.720001        NaN        NaN  90.860001          NaN
# 43621        NaN  78.369995        NaN        NaN  86.750000          NaN
# 43622        NaN   1.117952        NaN        NaN   1.083950          NaN
# 43623        NaN  88.849998        NaN        NaN  94.699997          NaN
#
# [43624 rows x 68 columns]

# %% [markdown]
# ## Finding the best year with most data

# %%
columns = df1.columns.to_list()
years = ['2018']
#uncomment this line to look at amount of data data for each year
#years = ['2018', '2019', '2020', '2021', '2022']
for x in years:
    df2 = df1.copy()
    df2 = df2.loc[:, ['Country Name','Indicator Name', x]]
    df2 = df2.pivot(index = 'Country Name', columns = 'Indicator Name', values = x)
    columns = df2.columns.to_list()
    indicators = []
    values = []
    for column in columns:
        if len(df2[column].unique()) > 200:
            indicators.append(column)
            values.append(len(df2[column].unique()))

    good_indicators = pd.DataFrame({'Indicators': indicators,
                                    'Number of Rows with Data': values})
    print(x)   
    #print((good_indicators))
good_indicators
# Out:
# 2018
#                                            Indicators  \
# 0        Labor force, female (% of total labor force)
# 1                                  Labor force, total
# 2                   Number of deaths ages 10-14 years
# 3                   Number of deaths ages 15-19 years
# 4                   Number of deaths ages 20-24 years
# 5                     Number of deaths ages 5-9 years
# 6        Population ages 0-14 (% of total population)
# 7       Population ages 15-64 (% of total population)
# 8                           Primary education, pupils
# 9             School enrollment, preprimary (% gross)
# 10               School enrollment, primary (% gross)
# 11  School enrollment, primary (gross), gender par...
# 12       School enrollment, primary, female (% gross)
# 13         School enrollment, primary, male (% gross)
# 14  Unemployment, female (% of female labor force)...
# 15  Unemployment, male (% of male labor force) (mo...
# 16  Unemployment, total (% of total labor force) (...
#
#     Number of Rows with Data
# 0                        233
# 1                        233
# 2                        203
# 3                        222
# 4                        224
# 5                        203
# 6                        264
# 7                        264
# 8                        217
# 9                        202
# 10                       211
# 11                       204
# 12                       210
# 13                       210
# 14                       228
# 15                       232
# 16                       228

# %%
# creates best dataset
df3 = df2.loc[:, indicators]
df3
# Out:
# Indicator Name               Labor force, female (% of total labor force)  \
# Country Name
# Afghanistan                                                     22.758726
# Africa Eastern and Southern                                     47.253574
# Africa Western and Central                                      44.338121
# Albania                                                         43.392704
# Algeria                                                         19.460834
# ...                                                                   ...
# West Bank and Gaza                                              20.615678
# World                                                           39.277186
# Yemen, Rep.                                                      7.827071
# Zambia                                                          45.692328
# Zimbabwe                                                        50.511193
#
# Indicator Name               Labor force, total  \
# Country Name
# Afghanistan                        9.613728e+06
# Africa Eastern and Southern        2.635412e+08
# Africa Western and Central         1.534623e+08
# Albania                            1.409389e+06
# Algeria                            1.222143e+07
# ...                                         ...
# West Bank and Gaza                 1.191792e+06
# World                              3.393224e+09
# Yemen, Rep.                        6.894546e+06
# Zambia                             5.789287e+06
# Zimbabwe                           5.770226e+06
#
# Indicator Name               Number of deaths ages 10-14 years  \
# Country Name
# Afghanistan                                             1958.0
# Africa Eastern and Southern                            89307.0
# Africa Western and Central                             85188.0
# Albania                                                   38.0
# Algeria                                                 1153.0
# ...                                                        ...
# West Bank and Gaza                                       213.0
# World                                                 363577.0
# Yemen, Rep.                                             1966.0
# Zambia                                                  1905.0
# Zimbabwe                                                2615.0
#
# Indicator Name               Number of deaths ages 15-19 years  \
# Country Name
# Afghanistan                                            11959.0
# Africa Eastern and Southern                           148796.0
# Africa Western and Central                             91246.0
# Albania                                                   75.0
# Algeria                                                 1519.0
# ...                                                        ...
# West Bank and Gaza                                       373.0
# World                                                 602862.0
# Yemen, Rep.                                             6538.0
# Zambia                                                  3665.0
# Zimbabwe                                                3480.0
#
# Indicator Name               Number of deaths ages 20-24 years  \
# Country Name
# Afghanistan                                            13358.0
# Africa Eastern and Southern                           166725.0
# Africa Western and Central                             97712.0
# Albania                                                  101.0
# Algeria                                                 2117.0
# ...                                                        ...
# West Bank and Gaza                                       472.0
# World                                                 744725.0
# Yemen, Rep.                                            10981.0
# Zambia                                                  4321.0
# Zimbabwe                                                4214.0
#
# Indicator Name               Number of deaths ages 5-9 years  \
# Country Name
# Afghanistan                                           2842.0
# Africa Eastern and Southern                         150575.0
# Africa Western and Central                          170197.0
# Albania                                                 32.0
# Algeria                                               1488.0
# ...                                                      ...
# West Bank and Gaza                                     237.0
# World                                               512474.0
# Yemen, Rep.                                           3935.0
# Zambia                                                3875.0
# Zimbabwe                                              2203.0
#
# Indicator Name               Population ages 0-14 (% of total population)  \
# Country Name
# Afghanistan                                                     44.708445
# Africa Eastern and Southern                                     42.052776
# Africa Western and Central                                      43.721214
# Albania                                                         17.083082
# Algeria                                                         30.208065
# ...                                                                   ...
# West Bank and Gaza                                              39.968222
# World                                                           26.066281
# Yemen, Rep.                                                     40.820397
# Zambia                                                          44.496183
# Zimbabwe                                                        41.798795
#
# Indicator Name               Population ages 15-64 (% of total population)  \
# Country Name
# Afghanistan                                                      52.884462
# Africa Eastern and Southern                                      54.834273
# Africa Western and Central                                       53.386094
# Albania                                                          68.066585
# Algeria                                                          64.121529
# ...                                                                    ...
# West Bank and Gaza                                               56.737043
# World                                                            64.966738
# Yemen, Rep.                                                      56.433893
# Zambia                                                           53.810028
# Zimbabwe                                                         54.907846
#
# Indicator Name               Primary education, pupils  \
# Country Name
# Afghanistan                                  6544906.0
# Africa Eastern and Southern                112928976.0
# Africa Western and Central                  64573820.0
# Albania                                       170861.0
# Algeria                                      4429994.0
# ...                                                ...
# West Bank and Gaza                            488184.0
# World                                      732499648.0
# Yemen, Rep.                                        NaN
# Zambia                                       3339245.0
# Zimbabwe                                     2725970.0
#
# Indicator Name               School enrollment, preprimary (% gross)  \
# Country Name
# Afghanistan                                                      NaN
# Africa Eastern and Southern                                28.961510
# Africa Western and Central                                 23.339550
# Albania                                                    80.498734
# Algeria                                                          NaN
# ...                                                              ...
# West Bank and Gaza                                         56.479252
# World                                                      60.067478
# Yemen, Rep.                                                      NaN
# Zambia                                                           NaN
# Zimbabwe                                                   69.689369
#
# Indicator Name               School enrollment, primary (% gross)  \
# Country Name
# Afghanistan                                            107.780533
# Africa Eastern and Southern                            104.289360
# Africa Western and Central                              88.606934
# Albania                                                107.403679
# Algeria                                                108.703484
# ...                                                           ...
# West Bank and Gaza                                      96.747879
# World                                                   99.394630
# Yemen, Rep.                                                   NaN
# Zambia                                                  97.770737
# Zimbabwe                                                97.879272
#
# Indicator Name               School enrollment, primary (gross), gender parity index (GPI)  \
# Country Name
# Afghanistan                                                            0.66691
# Africa Eastern and Southern                                            0.95805
# Africa Western and Central                                             0.95494
# Albania                                                                1.03765
# Algeria                                                                0.95499
# ...                                                                        ...
# West Bank and Gaza                                                     1.00261
# World                                                                  0.98221
# Yemen, Rep.                                                                NaN
# Zambia                                                                     NaN
# Zimbabwe                                                               0.99664
#
# Indicator Name               School enrollment, primary, female (% gross)  \
# Country Name
# Afghanistan                                                     86.190132
# Africa Eastern and Southern                                    101.823479
# Africa Western and Central                                      86.300819
# Albania                                                        104.839172
# Algeria                                                        106.400612
# ...                                                                   ...
# West Bank and Gaza                                              95.823601
# World                                                           98.396408
# Yemen, Rep.                                                           NaN
# Zambia                                                          98.672287
# Zimbabwe                                                        96.429039
#
# Indicator Name               School enrollment, primary, male (% gross)  \
# Country Name
# Afghanistan                                                  128.287537
# Africa Eastern and Southern                                  106.722160
# Africa Western and Central                                    90.853508
# Albania                                                      109.826767
# Algeria                                                      110.903572
# ...                                                                 ...
# West Bank and Gaza                                            97.651527
# World                                                        100.329697
# Yemen, Rep.                                                         NaN
# Zambia                                                        96.864098
# Zimbabwe                                                      99.360138
#
# Indicator Name               Unemployment, female (% of female labor force) (modeled ILO estimate)  \
# Country Name
# Afghanistan                                                          13.924000
# Africa Eastern and Southern                                           7.417153
# Africa Western and Central                                            4.196894
# Albania                                                              11.876000
# Algeria                                                              18.588000
# ...                                                                        ...
# West Bank and Gaza                                                   41.621000
# World                                                                 5.718692
# Yemen, Rep.                                                          25.272000
# Zambia                                                                5.090000
# Zimbabwe                                                              6.566000
#
# Indicator Name               Unemployment, male (% of male labor force) (modeled ILO estimate)  \
# Country Name
# Afghanistan                                                          10.281000
# Africa Eastern and Southern                                           6.461406
# Africa Western and Central                                            4.205429
# Albania                                                              12.625000
# Algeria                                                               8.442000
# ...                                                                        ...
# West Bank and Gaza                                                   22.271000
# World                                                                 5.684928
# Yemen, Rep.                                                          12.040000
# Zambia                                                                4.980000
# Zimbabwe                                                              7.007000
#
# Indicator Name               Unemployment, total (% of total labor force) (modeled ILO estimate)
# Country Name
# Afghanistan                                                          11.110000
# Africa Eastern and Southern                                           6.913046
# Africa Western and Central                                            4.201599
# Albania                                                              12.300000
# Algeria                                                              10.416000
# ...                                                                        ...
# West Bank and Gaza                                                   26.260000
# World                                                                 5.698210
# Yemen, Rep.                                                          13.076000
# Zambia                                                                5.030000
# Zimbabwe                                                              6.784000
#
# [266 rows x 17 columns]

# %%
# test
import matplotlib.pyplot as plt

plt.scatter(df3['Number of deaths ages 10-14 years'], df3['Number of deaths ages 15-19 years'])
